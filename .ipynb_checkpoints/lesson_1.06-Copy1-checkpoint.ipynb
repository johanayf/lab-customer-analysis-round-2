# %% [markdown]
# # Lesson 1.6

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import warnings
warnings.filterwarnings('ignore')
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns 
 
# %matplotlib inline

# %%
df = pd.read_csv('merged_clean_ver1.csv')

# %% [markdown]
# # Distributions
# ## What?
# - function that describes the relationship between observations in a sample space.
# - a function or a listing which shows all the possible values (or intervals) of the data. It also (and this is important) tells you how often each value occurs. Often, the data in a distribution will be ordered from smallest to largest, and graphs and charts allow you to easily see both the values and the frequency with which they appear.
#
# ## why?
# - Help us  to summarize the relationship of observations.
# - A sample of data will form a distribution, and by far the most well-known distribution is the Gaussian distribution, often called the Normal distribution. The distribution provides a parameterized mathematical function that can be used to calculate the probability for any individual observation from the sample space.
# - or the likelihood that an observation will have a value which is less than (or greater than) a point of interest.

# %% [markdown]
# ### What is a discrete distribution?
#
# A discrete distribution describes the probability of occurrence of each value of a discrete random variable. A discrete random variable is a random variable that has countable values, such as a list of non-negative integers.
#
# With a discrete probability distribution, each possible value of the discrete random variable can be associated with a non-zero probability. Thus, a discrete probability distribution is often presented in tabular form.
#
# Some examples of discrete probability distributions are Bernoulli distribution, Binomial distribution, Poisson distribution etc.
#
# ### Example of the number of customer complaints.
#
# With a discrete distribution, unlike with a continuous distribution, you can calculate the probability that X is exactly equal to some value. For example, you can use the discrete Poisson distribution to describe the number of customer complaints within a day. Suppose the average number of complaints per day is 10 and you want to know the probability of receiving 5, 10, and 15 customer complaints in a day.
# - x	P (X = x)
# - 5	0.037833
# - 10	0.125110
# - 15	0.034718
#
# You can also view a discrete distribution on a distribution plot to see the probabilities between ranges.

# %% [markdown]
# ## What is a continuous distribution?
# A continuous distribution describes the probabilities of the possible values of a continuous random variable. A continuous random variable is a random variable with a set of possible values (known as the range) that is infinite and uncountable.
#
# ## For example
#
# below with python

# %% [markdown]
# # Random Variables
# The possible values of the temperature outside on any given day.
#
# A random variable is a variable whose possible values are numerical outcomes of a random phenomenon. There are two types of random variables, discrete and continuous.
#
# - A discrete random variable is one which may take on only a countable number of distinct values and thus can be quantified. For example, you can define a random variable X to be the number which comes up when you roll a fair dice. X can take values : [1,2,3,4,5,6] and therefore is a discrete random variable.
#
# -

# %%
df
# Out:
#       Unnamed: 0      id state gender  median_home_val  \
# 0              0   44060    FL      M      1158.437751
# 1              1   96093    IL      M       537.000000
# 2              2   43333    FL      F       725.000000
# 3              3   21885    NC      M      1158.437751
# 4              4  190108    FL      F       995.000000
# ...          ...     ...   ...    ...              ...
# 3988         996   66762    MI      F       632.000000
# 3989         997    6443    FL      M       595.000000
# 3990         998  151175    CA      F      2707.000000
# 3991         999  151504    CA      M      2666.000000
# 3992        1000   74303    MI      M       444.000000
#
#       median_household_income    ic2  ic3    ic4      ic5  avggift  target_d
# 0                         392  430.0  466  520.0  21975.0       28     100.0
# 1                         365  415.0  410  473.0  19387.0        5       7.0
# ...

# %%
df.drop('Unnamed: 0', axis= 1, inplace = True)

# %%
df.columns
# Out:
# Index(['id', 'state', 'gender', 'median_home_val', 'median_household_income',
#        'ic2', 'ic3', 'ic4', 'ic5', 'avggift', 'target_d'],
#       dtype='object')

# %%
df
# Out:
#           id state gender  median_home_val  median_household_income    ic2  \
# 0      44060    FL      M      1158.437751                      392  430.0
# 1      96093    IL      M       537.000000                      365  415.0
# 2      43333    FL      F       725.000000                      301  340.0
# 3      21885    NC      M      1158.437751                      401  407.0
# 4     190108    FL      F       995.000000                      252  280.0
# ...      ...   ...    ...              ...                      ...    ...
# 3988   66762    MI      F       632.000000                      279  336.0
# 3989    6443    FL      M       595.000000                      252  263.0
# 3990  151175    CA      F      2707.000000                      507  504.0
# 3991  151504    CA      M      2666.000000                      535  609.0
# 3992   74303    MI      M       444.000000                      225  264.0
#
#       ic3    ic4      ic5  avggift  target_d
# ...

# %%
df.median_home_val.hist(bins = 100)
# Out:
# <AxesSubplot:>

# %%
len(df.state.unique())
# Out:
# 52

# %%
df.state.hist(bins = 100)
#the frecuencies of continues values in our samplimg experiment of getting the data 
# what are we seeing are ranges of data and the frecuencies of those ranges 
## continous data 
# the sampling was taked over a infinite set of values, the positive real numbers
# Out:
# <AxesSubplot:>

# %%
df.gender.unique()
# Out:
# array(['M', 'F', 'female', 'Male', 'U', 'J', 'male', 'Female', 'feamale',
#        'A'], dtype=object)

# %%
df.gender.hist(bins= 10)
# Out:
# <AxesSubplot:>

# %%
#there are some states with different names 
#the sampling here is over finite set of values : the states of usa

# %%
# just giving frecuencies of determined values in a countable set of values

# %% [markdown]
# Once you understand the distribution of a variable, the next step is often to ask whether features of that distribution differ across other variables in the dataset. For example, what accounts for the bimodal distribution of flipper lengths that we saw above? displot() and histplot() provide support for conditional subsetting via the hue semantic. Assigning a variable to hue will draw a separate histogram for each of its unique values and distinguish them by color:

# %% [markdown]
# Types of distributions
# ![image.png](attachment:image.png)

# %%
sns.displot(df, x='median_home_val', hue = 'gender')
plt.show()

# %%
## focusing on continous distributions

# %%
sns.displot(df, x='state', hue ='gender')

# %%
## generating random samples

# %% [markdown]
# # Lesson 1

# %%
## the most famous one

# %% [markdown]
# # Normal Distribution
# Gaussian  distribution.  The general form of its probability density function is
#
#
# ![image.png](attachment:image.png)

# %%
help(np.random.randn)
# Out:
# Help on built-in function randn:
#
# randn(...) method of numpy.random.mtrand.RandomState instance
#     randn(d0, d1, ..., dn)
#
#     Return a sample (or samples) from the "standard normal" distribution.
#
#     .. note::
#         This is a convenience function for users porting code from Matlab,
#         and wraps `standard_normal`. That function takes a
#         tuple to specify the size of the output, which is consistent with
#         other NumPy functions like `numpy.zeros` and `numpy.ones`.
#
#     .. note::
#         New code should use the ``standard_normal`` method of a ``default_rng()``
#         instance instead; please see the :ref:`random-quick-start`.
#
#     If positive int_like arguments are provided, `randn` generates an array
#     of shape ``(d0, d1, ..., dn)``, filled
#     with random floats sampled from a univariate "normal" (Gaussian)
#     distribution of mean 0 and variance 1. A single float randomly sampled
# ...

# %%
plt.hist(np.random.randn(1000), bins= 50)
plt.show()

# %%
sns.distplot(np.random.randn(1000),bins= 100, 
            color = 'blue')
plt.show()

# %% [markdown]
# You can generate a normally distributed random variable using scipy.stats module's norm.rvs() method. The loc argument corresponds to the mean of the distribution. scale corresponds to standard deviation and size to the number of random variates. If you want to maintain reproducibility, include a random_state argument assigned to a number.

# %%
from scipy.stats import norm 
data_normal = norm.rvs(size=1000, loc= 4, scale= 3)

# %%
help(norm)
# Out:
# Help on norm_gen in module scipy.stats._continuous_distns object:
#
# class norm_gen(scipy.stats._distn_infrastructure.rv_continuous)
#  |  norm_gen(momtype=1, a=None, b=None, xtol=1e-14, badvalue=None, name=None, longname=None, shapes=None, extradoc=None, seed=None)
#  |
#  |  A normal continuous random variable.
#  |
#  |  The location (``loc``) keyword specifies the mean.
#  |  The scale (``scale``) keyword specifies the standard deviation.
#  |
#  |  %(before_notes)s
#  |
#  |  Notes
#  |  -----
#  |  The probability density function for `norm` is:
#  |
#  |  .. math::
#  |
#  |      f(x) = \frac{\exp(-x^2/2)}{\sqrt{2\pi}}
#  |
#  |  for a real number :math:`x`.
#  |
#  |  %(after_notes)s
#  |
#  |  %(example)s
#  |
#  |  Method resolution order:
#  |      norm_gen
#  |      scipy.stats._distn_infrastructure.rv_continuous
#  |      scipy.stats._distn_infrastructure.rv_generic
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  fit(self, data, **kwds)
# ...

# %%
## norm generates random numbers as sample data

# %%
sns.distplot(data_normal, bins=100, color= 'blue')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# activity 1
#
# - https://github.com/ironhack-edu/data_1.06_activities/blob/master/1.06_activity_1.md

# %% [markdown]
# # Lesson 2

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
# apply linear regression on the following data

# %% [markdown]
# Linear Regression
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The Seven Classical OLS Assumption
# - 1 The regression model is linear in the coefficients and the error term
# - 2 The error term has a population mean of zero
# - 3 All independent variables are uncorrelated with the error term
# - 4 Observations of the error term are uncorrelated with each other
# - 5 The error term has a constant variance (no heteroscedasticity)
# - 6 No independent variable is a perfect linear function of other explanatory variables
# - 7 The error term is normally distributed (optional)

# %%
data = pd.read_csv('regression_data1.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-53c69071e21d> in <module>
# ----> 1 data = pd.read_csv('regression_data1.csv')
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# ...

# %%
import pandas as pd

# %%
data.head()
# Out:
#     HV1  IC1  IC2  IC3  IC4    IC5    AVGGIFT  TARGET_D
# 0  2346  420  446  468  503  14552  15.500000      21.0
# 1   497  350  364  357  384  11696   3.080000       3.0
# 2  1229  469  502  507  544  17313   7.500000      20.0
# 3   325  148  181  171  209   6334   6.700000       5.0
# 4   768  174  201  220  249   7802   8.785714      10.0

# %%
Y = data['TARGET_D']
X = data.drop('TARGET_D', axis= 1)
lm = linear_model.LinearRegression()
lm.fit(X,Y)
# Out:
# LinearRegression()

# %%
lm.score(X,Y)
# Out:
# 0.2721089888340975

# %%
lm.intercept_
# Out:
# 6.20922387315664

# %%
lm.coef_
# Out:
# array([ 9.69296995e-05, -2.00305674e-03,  9.84630309e-05, -2.21132354e-03,
#         6.71311365e-03,  3.09166582e-05,  6.21136417e-01])

# %%
import statsmodels.api as sm 
from statsmodels.formula.api import ols
Y = data['TARGET_D']
X = data.drop('TARGET_D', axis= 1)
X = sm.add_constant(X)
model = sm.OLS(Y,X).fit()
print(model.summary())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-181d81b2992e> in <module>
#       1 import statsmodels.api as sm
#       2 from statsmodels.formula.api import ols
# ----> 3 Y = data['TARGET_D']
#       4 X = data.drop('TARGET_D', axis= 1)
#       5 X = sm.add_constant(X)
#
# NameError: name 'data' is not defined

# %% [markdown]
# what's important from the summary
# ![image.png](attachment:image.png)

# %%
# discuss in more details about the intercept, coefficients, OLS etc in the next section

# %% [markdown]
# # Lesson 4

# %%
correlations_matrix = data.corr()
mask = np.zeros_like(correlations_matrix)
mask[np.triu_indices_from(mask)] = True
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(correlations_matrix, mask=mask, annot=True)
plt.show()

# %%
# We can see that there is a very strong positive correlation between IC1 and IC2, IC2 and IC3, IC3 and IC4
# using the concept of multicollinearity, lets drop IC2, IC3 and IC4

# %%
data = data.drop(['IC2', 'IC3', 'IC4'],axis=1)

# %%
data.columns
# Out:
# Index(['HV1', 'IC1', 'IC5', 'AVGGIFT', 'TARGET_D'], dtype='object')

# %%
correlations_matrix = data.corr()
mask = np.zeros_like(correlations_matrix)
mask[np.triu_indices_from(mask)] = True
fig, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(correlations_matrix, mask=mask, annot=True)
plt.show()

# %% [markdown]
# ACTIVITY 2
# - https://github.com/ironhack-edu/data_1.06_activities/blob/master/1.06_activity_2.md
